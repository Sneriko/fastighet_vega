# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
df = pd.read_csv('/home/erik/Riksarkivet/Projects/fastighet/output/iteration3_epoch3_flipside_choice_eval.txt', sep='\s', index_col=0)
# Out:
# /home/erik/anaconda3/envs/openmmlab/lib/python3.7/site-packages/pandas/util/_decorators.py:311: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   return func(*args, **kwargs)

# %%
df.hist(column='HIT_RATE', rwidth=0.95, bins=20, figsize=(30,10), ylabelsize=10)
# Out:
# array([[<AxesSubplot:title={'center':'HIT_RATE'}>]], dtype=object)

# %%
x.plot()
# Out:
# []
