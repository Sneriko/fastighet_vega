# %%
from glob import glob
import os

# %%
imgs = glob(os.path.join('/ceph/hpc/home/euerikl/projects/fastighet/data/pipeline_test_data/batches', '**', '**'))
print(len(imgs))
# Out:
# 2966

# %%
imgs.sort()
